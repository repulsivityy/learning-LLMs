# %% [markdown]
# <a href="https://colab.research.google.com/github/repulsivityy/learning-LLMs/blob/main/Learning_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imports and clones github repo
import os

REPO_URL = "https://github.com/repulsivityy/learning-LLMs.git"
REPO_DIR = "/content/learning-LLMs"

if not os.path.exists(REPO_DIR):
    # !git clone {REPO_URL} {REPO_DIR}
# %cd {REPO_DIR}
# Out:
# Cloning into '/content/learning-LLMs'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 9 (delta 1), reused 8 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (9/9), 9.16 KiB | 9.16 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# /content/learning-LLMs

# %%
# Sets up the Github Token (learning_llm)

from google.colab import userdata
token = userdata.get('GITHUB_TOKEN')
# !git remote set-url origin https://{token}@github.com/repulsivityy/learning-LLMs.git

# %%
# Installs numpy
# !pip install -q torch numpy

# %%
# Creates the relevant notebooks

# src/ — reusable code (e.g. src/tokenizer.py) that you import into the notebook. This is what you git add/commit/push from the cells above.
# notebooks/ — the actual .ipynb. Easiest way to save it there: File → Save a copy in GitHub, choose repulsivityy/learning-LLMs, path notebooks/00_mechanics.ipynb. That commits the notebook itself directly, separate from the src/ git cells.

# !mkdir -p notebooks src
